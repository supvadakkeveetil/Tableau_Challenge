# %% [markdown]
# # Data Exploration and Cleaning

# %% [markdown]
# ###### 1. Import Libraries and dependencies (example- matplotlib, scipy, numpy and pandas)

# %%
# Importing the Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# %% [markdown]
# ###### 2. Load data into the Dataframe (df) from Excel /CSV files

# %%
#Reading data from CSV and creating a Pandas Data Frame for 2019 DECEMBER Data
Citibike_2019_dec_path ="data_1/JC-201912-citibike-tripdata.csv"
Citibike_2019_Dec = pd.read_csv(Citibike_2019_dec_path)

# %% [markdown]
# ###### 3. Preliminary Data Examination

# %%
#Checking the data in the data frame(df) and its structure
Citibike_2019_Dec.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1553  2019-12-01 00:07:13.9360  2019-12-01 00:33:07.6820
# 1           416  2019-12-01 00:16:40.4700  2019-12-01 00:23:36.5700
# 2           294  2019-12-01 00:20:29.7980  2019-12-01 00:25:23.9690
# 3            97  2019-12-01 00:21:13.7580  2019-12-01 00:22:51.5970
# 4           286  2019-12-01 00:29:58.0230  2019-12-01 00:34:44.2280
#
#    start station id start station name  start station latitude  \
# 0              3681           Grand St               40.715178
# 1              3195            Sip Ave               40.730897
# 2              3195            Sip Ave               40.730897
# 3              3202       Newport PATH               40.727224
# 4              3195            Sip Ave               40.730897
#
#    start station longitude  end station id  end station name  \
# 0               -74.037683            3198  Heights Elevator
# ...

# %%
Citibike_2019_Dec.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19728 entries, 0 to 19727
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   tripduration             19728 non-null  int64
#  1   starttime                19728 non-null  object
#  2   stoptime                 19728 non-null  object
#  3   start station id         19728 non-null  int64
#  4   start station name       19728 non-null  object
#  5   start station latitude   19728 non-null  float64
#  6   start station longitude  19728 non-null  float64
#  7   end station id           19728 non-null  int64
#  8   end station name         19728 non-null  object
#  9   end station latitude     19728 non-null  float64
#  10  end station longitude    19728 non-null  float64
#  11  bikeid                   19728 non-null  int64
#  12  usertype                 19728 non-null  object
#  13  birth year               19728 non-null  int64
# ...

# %%
Citibike_2019_Dec['starttime']=pd.to_datetime(Citibike_2019_Dec['starttime'])
Citibike_2019_Dec['stoptime']=pd.to_datetime(Citibike_2019_Dec['stoptime'])
Citibike_2019_Dec.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19728 entries, 0 to 19727
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   tripduration             19728 non-null  int64
#  1   starttime                19728 non-null  datetime64[ns]
#  2   stoptime                 19728 non-null  datetime64[ns]
#  3   start station id         19728 non-null  int64
#  4   start station name       19728 non-null  object
#  5   start station latitude   19728 non-null  float64
#  6   start station longitude  19728 non-null  float64
#  7   end station id           19728 non-null  int64
#  8   end station name         19728 non-null  object
#  9   end station latitude     19728 non-null  float64
#  10  end station longitude    19728 non-null  float64
#  11  bikeid                   19728 non-null  int64
#  12  usertype                 19728 non-null  object
# ...

# %%
#Reading data from CSV and creating a Pandas Data Frame for 2019 NOVEMBER data
Citibike_2019_nov_path ="data_1/JC-201911-citibike-tripdata.csv"
Citibike_2019_Nov = pd.read_csv(Citibike_2019_nov_path)

# %%
Citibike_2019_Nov.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30797 entries, 0 to 30796
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   tripduration             30797 non-null  int64
#  1   starttime                30797 non-null  object
#  2   stoptime                 30797 non-null  object
#  3   start station id         30797 non-null  int64
#  4   start station name       30797 non-null  object
#  5   start station latitude   30797 non-null  float64
#  6   start station longitude  30797 non-null  float64
#  7   end station id           30797 non-null  int64
#  8   end station name         30797 non-null  object
#  9   end station latitude     30797 non-null  float64
#  10  end station longitude    30797 non-null  float64
#  11  bikeid                   30797 non-null  int64
#  12  usertype                 30797 non-null  object
#  13  birth year               30797 non-null  int64
# ...

# %%
#Converting to Date Time format
Citibike_2019_Nov['starttime']=pd.to_datetime(Citibike_2019_Nov['starttime'])
Citibike_2019_Nov['stoptime']=pd.to_datetime(Citibike_2019_Nov['stoptime'])
Citibike_2019_Nov.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30797 entries, 0 to 30796
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   tripduration             30797 non-null  int64
#  1   starttime                30797 non-null  datetime64[ns]
#  2   stoptime                 30797 non-null  datetime64[ns]
#  3   start station id         30797 non-null  int64
#  4   start station name       30797 non-null  object
#  5   start station latitude   30797 non-null  float64
#  6   start station longitude  30797 non-null  float64
#  7   end station id           30797 non-null  int64
#  8   end station name         30797 non-null  object
#  9   end station latitude     30797 non-null  float64
#  10  end station longitude    30797 non-null  float64
#  11  bikeid                   30797 non-null  int64
#  12  usertype                 30797 non-null  object
# ...

# %%
Citibike_2019_Nov.head()
# Out:
#    tripduration               starttime                stoptime  \
# 0           260 2019-11-01 00:02:53.886 2019-11-01 00:07:14.645
# 1           285 2019-11-01 00:05:38.636 2019-11-01 00:10:24.193
# 2           501 2019-11-01 00:05:43.631 2019-11-01 00:14:05.481
# 3           556 2019-11-01 00:07:57.055 2019-11-01 00:17:13.901
# 4           321 2019-11-01 00:11:44.566 2019-11-01 00:17:05.593
#
#    start station id start station name  start station latitude  \
# 0              3186      Grove St PATH               40.719586
# 1              3206            Hilltop               40.731169
# 2              3186      Grove St PATH               40.719586
# 3              3209       Brunswick St               40.724176
# 4              3273       Manila & 1st               40.721651
#
#    start station longitude  end station id    end station name  \
# 0               -74.043117            3203       Hamilton Park
# 1               -74.057574            3212     Christ Hospital
# ...

# %%
#Reading data from CSV and creating a Pandas Data Frame for 2019 OCTOBER Data
Citibike_2019_oct_path ="data_1/JC-201910-citibike-tripdata.csv"
Citibike_2019_Oct= pd.read_csv(Citibike_2019_oct_path)

# %%
Citibike_2019_Oct.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42253 entries, 0 to 42252
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   tripduration             42253 non-null  int64
#  1   starttime                42253 non-null  object
#  2   stoptime                 42253 non-null  object
#  3   start station id         42253 non-null  int64
#  4   start station name       42253 non-null  object
#  5   start station latitude   42253 non-null  float64
#  6   start station longitude  42253 non-null  float64
#  7   end station id           42253 non-null  int64
#  8   end station name         42253 non-null  object
#  9   end station latitude     42253 non-null  float64
#  10  end station longitude    42253 non-null  float64
#  11  bikeid                   42253 non-null  int64
#  12  usertype                 42253 non-null  object
#  13  birth year               42253 non-null  int64
# ...

# %%
#Converting to Date Time format
Citibike_2019_Oct['starttime']=pd.to_datetime(Citibike_2019_Oct['starttime'])
Citibike_2019_Oct['stoptime']=pd.to_datetime(Citibike_2019_Oct['stoptime'])
Citibike_2019_Oct.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42253 entries, 0 to 42252
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   tripduration             42253 non-null  int64
#  1   starttime                42253 non-null  datetime64[ns]
#  2   stoptime                 42253 non-null  datetime64[ns]
#  3   start station id         42253 non-null  int64
#  4   start station name       42253 non-null  object
#  5   start station latitude   42253 non-null  float64
#  6   start station longitude  42253 non-null  float64
#  7   end station id           42253 non-null  int64
#  8   end station name         42253 non-null  object
#  9   end station latitude     42253 non-null  float64
#  10  end station longitude    42253 non-null  float64
#  11  bikeid                   42253 non-null  int64
#  12  usertype                 42253 non-null  object
# ...

# %%
#Citibike_2021_clean = Citibike_2021.dropna()
#Citibike_2021_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47662 entries, 0 to 48020
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ride_id             47662 non-null  object
#  1   rideable_type       47662 non-null  object
#  2   started_at          47662 non-null  datetime64[ns]
#  3   ended_at            47662 non-null  datetime64[ns]
#  4   start_station_name  47662 non-null  object
#  5   start_station_id    47662 non-null  object
#  6   end_station_name    47662 non-null  object
#  7   end_station_id      47662 non-null  object
#  8   start_lat           47662 non-null  float64
#  9   start_lng           47662 non-null  float64
#  10  end_lat             47662 non-null  float64
#  11  end_lng             47662 non-null  float64
#  12  member_casual       47662 non-null  object
# dtypes: datetime64[ns](2), float64(4), object(7)
# memory usage: 5.1+ MB

# %%
#Combining all 3 files (Data from 2019 December , November and OCtober Months)
citybike_combined_df = pd.concat([Citibike_2019_Oct, Citibike_2019_Nov , Citibike_2019_Dec], ignore_index=True)

# %%
citybike_combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92778 entries, 0 to 92777
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   tripduration             92778 non-null  int64
#  1   starttime                92778 non-null  datetime64[ns]
#  2   stoptime                 92778 non-null  datetime64[ns]
#  3   start station id         92778 non-null  int64
#  4   start station name       92778 non-null  object
#  5   start station latitude   92778 non-null  float64
#  6   start station longitude  92778 non-null  float64
#  7   end station id           92778 non-null  int64
#  8   end station name         92778 non-null  object
#  9   end station latitude     92778 non-null  float64
#  10  end station longitude    92778 non-null  float64
#  11  bikeid                   92778 non-null  int64
#  12  usertype                 92778 non-null  object
# ...

# %%
citybike_combined_df.head()
# Out:
#    tripduration               starttime                stoptime  \
# 0           892 2019-10-01 00:20:05.014 2019-10-01 00:34:57.380
# 1           374 2019-10-01 00:43:48.879 2019-10-01 00:50:03.819
# 2           170 2019-10-01 01:35:51.863 2019-10-01 01:38:42.547
# 3           946 2019-10-01 02:55:53.400 2019-10-01 03:11:40.271
# 4           517 2019-10-01 03:10:16.129 2019-10-01 03:18:53.635
#
#    start station id start station name  start station latitude  \
# 0              3275     Columbus Drive               40.718355
# 1              3211         Newark Ave               40.721525
# 2              3194    McGinley Square               40.725340
# 3              3272       Jersey & 3rd               40.723332
# 4              3206            Hilltop               40.731169
#
#    start station longitude  end station id            end station name  \
# 0               -74.038914            3280                 Astor Place
# ...

# %%
# Saving the combined dataframe to CSV
citybike_combined_df.to_csv('data_1/citibike_combined_2019.csv',index=False)
